# %% [markdown]
# # OmniVoice Web UI (Google Colab) 🚀
#
# Buku catatan (*notebook*) ini sudah dioptimalkan khusus untuk menampilkan **Web UI OmniVoice** secara langsung menggunakan GPU gratis dari Google Colab.
#
# ### Cara Penggunaan:
# 1. Pastikan Colab menggunakan GPU. Buka menu **Runtime** > **Change runtime type** > Pilih **T4 GPU** > Klik **Save**.
# 2. Klik tombol ▶️ pada sel **Tahap 1** untuk menginstal OmniVoice. Tunggu hingga proses selesai.
# 3. Klik tombol ▶️ pada sel **Tahap 2** untuk menyalakan server.
# 4. Perhatikan teks log/output di bawah sel Tahap 2. Tunggu beberapa saat, lalu cari tulisan `Running on public URL:` dan klik **tautan yang berakhiran .gradio.live** untuk membuka Web UI.

# %%
# [ Tahap 1 ] Instalasi Dependensi
# Ini akan memakan waktu 1-2 menit untuk mengunduh library yang dibutuhkan.
# !pip install omnivoice

# %%
# [ Tahap 2 ] Menjalankan Web UI
# Menggunakan fitur --share dari Gradio untuk membuat public link aman (HTTPS) bebas dari Mixed Content
# !omnivoice-demo --share
